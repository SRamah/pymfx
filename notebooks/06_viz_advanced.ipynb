# %% [markdown]
# # pymfx — Advanced Visualization
#
# This notebook covers three advanced visualization functions:
#
# 1. **`speed_heatmap`** — interactive map with trajectory segments coloured green → red by speed
# 2. **`compare_map`** — multiple flights overlaid on the same map with a colour legend
# 3. **`flight_3d`** — three-dimensional matplotlib plot (longitude / latitude / altitude)
#
# **Requirements:**
# ```bash
# pip install pymfx[viz]   # folium + matplotlib
# ```

# %%
import sys, math, uuid
sys.path.insert(0, '..')  # if running from notebooks/

import matplotlib
matplotlib.use('Agg')   # use non-interactive backend for notebook rendering
import matplotlib.pyplot as plt

import pymfx
from pymfx import viz
from pymfx.models import (
    MfxFile, Meta, Trajectory, TrajectoryPoint, SchemaField,
    Events, Event, Index,
)
from pymfx import compute_checksum

print(f"pymfx {pymfx.__version__}")
# Out:
# pymfx 1.0.0

# %% [markdown]
# ## Build two demo missions
#
# We create two flights over the same general area with slightly different paths and speeds — one faster, one slower.

# %%
def make_mfx(
    drone_id: str,
    base_speed: float = 8.0,
    lat_offset: float = 0.0,
    date_start: str = '2026-05-10T08:00:00Z',
    date_end:   str = '2026-05-10T08:00:50Z',
    n: int = 50,
) -> MfxFile:
    BASE_LAT, BASE_LON = 43.2965 + lat_offset, 5.3698  # Marseille
    FREQ = 1.0

    raw_pts = [
        (
            round(float(i), 3),
            round(BASE_LAT + i * 0.00009, 7),
            round(BASE_LON + math.cos(i * 0.2) * 0.0003, 7),
            round(150.0 + math.sin(i * 0.25) * 15, 2),
            round(base_speed + math.sin(i * 0.3) * 2, 2),
            round((i * 7) % 360, 1),
        )
        for i in range(n)
    ]

    schema_fields = [
        SchemaField('t',        'float',   ['no_null']),
        SchemaField('lat',      'float',   ['no_null']),
        SchemaField('lon',      'float',   ['no_null']),
        SchemaField('alt_m',    'float32'),
        SchemaField('speed_ms', 'float32'),
        SchemaField('heading',  'float32'),
    ]
    points    = [TrajectoryPoint(t=r[0], lat=r[1], lon=r[2], alt_m=r[3], speed_ms=r[4], heading=r[5]) for r in raw_pts]
    raw_lines = [f"{r[0]:.3f} | {r[1]} | {r[2]} | {r[3]} | {r[4]} | {r[5]}" for r in raw_pts]

    ev_schema = [
        SchemaField('t',        'float', ['no_null']),
        SchemaField('type',     'str'),
        SchemaField('severity', 'str'),
        SchemaField('detail',   'str'),
    ]
    ev_list = [
        Event(t=0.0,  type='takeoff',  severity='info',    detail='ok'),
        Event(t=20.0, type='anomaly',  severity='warning', detail='wind'),
        Event(t=n-1,  type='landing',  severity='info',    detail='ok'),
    ]
    ev_raw = [f"{e.t:.3f} | {e.type} | {e.severity} | {e.detail}" for e in ev_list]

    lats = [p.lat for p in points];  lons = [p.lon for p in points]
    bbox = (round(min(lons), 7), round(min(lats), 7), round(max(lons), 7), round(max(lats), 7))

    return MfxFile(
        version='1.0', encoding='UTF-8',
        meta=Meta(
            id=f'uuid:{uuid.uuid4()}',
            drone_id=drone_id,
            drone_type='multirotor',
            pilot_id='FR-PILOT-0001',
            date_start=date_start,
            date_end=date_end,
            duration_s=n - 1,
            status='complete',
            application='inspection',
            location='Marseille, France',
            sensors=['rgb'],
            data_level='raw',
            license='CC-BY-4.0',
            contact='ops@inspect.fr',
        ),
        trajectory=Trajectory(
            frequency_hz=FREQ,
            schema_fields=schema_fields,
            points=points,
            checksum=compute_checksum(raw_lines),
            raw_lines=raw_lines,
        ),
        events=Events(
            schema_fields=ev_schema,
            events=ev_list,
            checksum=compute_checksum(ev_raw),
            raw_lines=ev_raw,
        ),
        index=Index(bbox=bbox, anomalies=1),
    )

mfx_fast = make_mfx('Mavic3-FAST-SN001', base_speed=12.0, lat_offset=0.000)
mfx_slow = make_mfx('Mavic3-SLOW-SN002', base_speed= 5.0, lat_offset=0.005)

print(pymfx.validate(mfx_fast))
print(pymfx.validate(mfx_slow))
# Out:
# ✓ Valid file — no issues found.
# ✓ Valid file — no issues found.

# %% [markdown]
# ## 1. Speed heatmap
#
# `speed_heatmap()` draws each trajectory segment as a coloured `PolyLine`.
# The colour scale (green = slow, red = fast) is computed from the actual speed range of the flight.

# %%
m_heat = viz.speed_heatmap(mfx_fast)
m_heat  # renders inline in Jupyter
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_153e643224e60699661054a4d7c52b19 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_153e643224e60699661054a4d7c52b19&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_153e643224e60699661054a4d7c52b19 = L.map(
#                 &quot;map_153e643224e60699661054a4d7c52b19&quot;,
#                 {
#                     center: [43.298705, 5.369789256000001],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bdfbf4e971e4f6bc80718aa5f2cf7347 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bdfbf4e971e4f6bc80718aa5f2cf7347.addTo(map_153e643224e60699661054a4d7c52b19);
#
#
#             var poly_line_0916c58e37af5d2760f8fbe61ffa5511 = L.polyline(
#                 [[43.2965, 5.3701], [43.29659, 5.370094]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ffff00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.9, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_153e643224e60699661054a4d7c52b19);
#
#
#             poly_line_0916c58e37af5d2760f8fbe61ffa5511.bindTooltip(
#                 `&lt;div&gt;
#                      t=0.0s  speed=12.00 m/s
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_67fe4937d08997c11b656b224a5a3c93 = L.polyline(
#                 [[43.29659, 5.370094], [43.29668, 5.3700763]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffb400ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ffb400ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.9, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_153e643224e60699661054a4d7c52b19);
#
#
#             poly_line_67fe4937d08997c11b656b224a5a3c93.bindTooltip(
#                 `&lt;div&gt;
#                      t=1.0s  speed=12.59 m/s
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_d8faf4a134d64b7f2cce4a0d3f02c4d0 = L.polyline(
#                 [[43.29668, 5.3700763], [43.29677, 5.3700476]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff6f00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ff6f00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.9, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_153e643224e60699661054a4d7c52b19);
#
#
#             poly_line_d8faf4a134d64b7f2cce4a0d3f02c4d0.bindTooltip(
#                 `&lt;div&gt;
#                      t=2.0s  speed=13.13 m/s
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_c61de6b7e71ab757e4fe1b3845b447a6 = L.polyline(
#                 [[43.29677, 5.3700476], [43.29686, 5.370009]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff3700ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ff3700ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.9, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_153e643224e60699661054a4d7c52b19);
#
#
#             poly_line_c61de6b7e71ab757e4fe1b3845b447a6.bindTooltip(
#                 `&lt;div&gt;

# %%
# Show event markers as well
m_heat_ev = viz.speed_heatmap(mfx_fast, show_events=True)
m_heat_ev.save('speed_heatmap.html')
print("Saved to speed_heatmap.html")
# Out:
# Saved to speed_heatmap.html

# %%
# Options: tile style, line weight
m_heat2 = viz.speed_heatmap(mfx_fast, tile='CartoDB positron', line_weight=6)
m_heat2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_870a4c3616fa1fc51f67c903e2b65ad0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_870a4c3616fa1fc51f67c903e2b65ad0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_870a4c3616fa1fc51f67c903e2b65ad0 = L.map(
#                 &quot;map_870a4c3616fa1fc51f67c903e2b65ad0&quot;,
#                 {
#                     center: [43.298705, 5.369789256000001],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e861b8601553b3b2be4f1f90bc449bb = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6e861b8601553b3b2be4f1f90bc449bb.addTo(map_870a4c3616fa1fc51f67c903e2b65ad0);
#
#
#             var poly_line_e7e44589c0f216fcebb2091111ea2907 = L.polyline(
#                 [[43.2965, 5.3701], [43.29659, 5.370094]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ffff00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.9, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_870a4c3616fa1fc51f67c903e2b65ad0);
#
#
#             poly_line_e7e44589c0f216fcebb2091111ea2907.bindTooltip(
#                 `&lt;div&gt;
#                      t=0.0s  speed=12.00 m/s
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_e1ee46c6018206ddca892aa66a605c73 = L.polyline(
#                 [[43.29659, 5.370094], [43.29668, 5.3700763]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffb400ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ffb400ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.9, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_870a4c3616fa1fc51f67c903e2b65ad0);
#
#
#             poly_line_e1ee46c6018206ddca892aa66a605c73.bindTooltip(
#                 `&lt;div&gt;
#                      t=1.0s  speed=12.59 m/s
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_a014052a5c441ac34605d872d938e637 = L.polyline(
#                 [[43.29668, 5.3700763], [43.29677, 5.3700476]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff6f00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ff6f00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.9, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_870a4c3616fa1fc51f67c903e2b65ad0);
#
#
#             poly_line_a014052a5c441ac34605d872d938e637.bindTooltip(
#                 `&lt;div&gt;
#                      t=2.0s  speed=13.13 m/s
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_0e619d1941ac3ece95ebddf840e4e5cb = L.polyline(
#                 [[43.29677, 5.3700476], [43.29686, 5.370009]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff3700ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ff3700ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.9, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_870a4c3616fa1fc51f67c903e2b65ad0);

# %% [markdown]
# ## 2. Compare map
#
# `compare_map()` overlays multiple flights on the same map using distinct colours.
# An auto-generated HTML legend identifies each flight by `drone_id` (or by a custom label).

# %%
# Default labels = drone_id from each flight's meta
m_compare = viz.compare_map([mfx_fast, mfx_slow])
m_compare
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b938d65a22d494b82e56d523801ec0a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;position:fixed;bottom:30px;left:30px;z-index:9999;
#                 background:white;padding:10px 14px;border-radius:8px;
#                 box-shadow:2px 2px 6px rgba(0,0,0,.25);font-size:13px&quot;&gt;
#         &lt;b&gt;Flights&lt;/b&gt;&lt;br&gt;
#         &lt;table style=&quot;border-collapse:collapse;margin-top:4px&quot;&gt;
#         &lt;tr&gt;&lt;td style=&quot;background:#1a73e8; width:16px; height:16px; border-radius:3px&quot;&gt;&lt;/td&gt;&lt;td style=&quot;padding-left:6px&quot;&gt;Mavic3-FAST-SN001&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td style=&quot;background:#e8341a; width:16px; height:16px; border-radius:3px&quot;&gt;&lt;/td&gt;&lt;td style=&quot;padding-left:6px&quot;&gt;Mavic3-SLOW-SN002&lt;/td&gt;&lt;/tr&gt;
#         &lt;/table&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b938d65a22d494b82e56d523801ec0a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b938d65a22d494b82e56d523801ec0a3 = L.map(
#                 &quot;map_b938d65a22d494b82e56d523801ec0a3&quot;,
#                 {
#                     center: [43.301205, 5.369789256000001],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eb55942697df63979659a4fd8b059ce1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eb55942697df63979659a4fd8b059ce1.addTo(map_b938d65a22d494b82e56d523801ec0a3);
#
#
#             var poly_line_d74b794cf7e90d606983dc6cf790695d = L.polyline(
#                 [[43.2965, 5.3701], [43.29659, 5.370094], [43.29668, 5.3700763], [43.29677, 5.3700476], [43.29686, 5.370009], [43.29695, 5.3699621], [43.29704, 5.3699087], [43.29713, 5.369851], [43.29722, 5.3697912], [43.29731, 5.3697318], [43.2974, 5.3696752], [43.29749, 5.3696234], [43.29758, 5.3695788], [43.29767, 5.3695429], [43.29776, 5.3695173], [43.29785, 5.369503], [43.29794, 5.3695005], [43.29803, 5.36951], [43.29812, 5.369531], [43.29821, 5.3695627], [43.2983, 5.3696039], [43.29839, 5.3696529], [43.29848, 5.3697078], [43.29857, 5.3697664], [43.29866, 5.3698262], [43.29875, 5.3698851], [43.29884, 5.3699406], [43.29893, 5.3699904], [43.29902, 5.3700327], [43.29911, 5.3700657], [43.2992, 5.3700881], [43.29929, 5.370099], [43.29938, 5.370098], [43.29947, 5.3700851], [43.29956, 5.3700608], [43.29965, 5.3700262], [43.29974, 5.3699825], [43.29983, 5.3699316], [43.29992, 5.3698754], [43.30001, 5.3698162], [43.3001, 5.3697563], [43.30019, 5.3696983], [43.30028, 5.3696442], [43.30037, 5.3695964], [43.30046, 5.3695567], [43.30055, 5.3695267], [43.30064, 5.3695075], [43.30073, 5.3695001], [43.30082, 5.3695046], [43.30091, 5.3695209]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1a73e8&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#1a73e8&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.85, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b938d65a22d494b82e56d523801ec0a3);
#
#
#             poly_line_d74b794cf7e90d606983dc6cf790695d.bindTooltip(
#                 `&lt;div&gt;
#                      Mavic3-FAST-SN001 — 50 points
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_9bbffc09aab510c2ea7115b2999418dc = L.marker(
#                 [43.2965, 5.3701],
#                 {
# }
#             ).addTo(map_b938d65a22d494b82e56d523801ec0a3);
#
#
#             var icon_73765cca22de6646cc7473ed36078851 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;play&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_9bbffc09aab510c2ea7115b2999418dc.bindTooltip(
#                 `&lt;div&gt;
#                      [Mavic3-FAST-SN001] Start
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_9bbffc09aab510c2ea7115b2999418dc.setIcon(icon_73765cca22de6646cc7473ed36078851);
#
#
#             var marker_f31723a666bf69c446be40bbe0b11b59 = L.marker(
#                 [43.

# %%
# Custom labels + show events
m_compare2 = viz.compare_map(
    [mfx_fast, mfx_slow],
    labels=['High-speed run', 'Low-speed run'],
    show_events=True,
)
m_compare2.save('compare_map.html')
print("Saved to compare_map.html")
# Out:
# Saved to compare_map.html

# %%
# Three flights at once
mfx_med = make_mfx('Mavic3-MED-SN003', base_speed=8.5, lat_offset=0.010)
m_three = viz.compare_map([mfx_fast, mfx_med, mfx_slow],
                          labels=['Fast', 'Medium', 'Slow'])
m_three
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6387e344feadefa6f96df50401a36971 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;position:fixed;bottom:30px;left:30px;z-index:9999;
#                 background:white;padding:10px 14px;border-radius:8px;
#                 box-shadow:2px 2px 6px rgba(0,0,0,.25);font-size:13px&quot;&gt;
#         &lt;b&gt;Flights&lt;/b&gt;&lt;br&gt;
#         &lt;table style=&quot;border-collapse:collapse;margin-top:4px&quot;&gt;
#         &lt;tr&gt;&lt;td style=&quot;background:#1a73e8; width:16px; height:16px; border-radius:3px&quot;&gt;&lt;/td&gt;&lt;td style=&quot;padding-left:6px&quot;&gt;Fast&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td style=&quot;background:#e8341a; width:16px; height:16px; border-radius:3px&quot;&gt;&lt;/td&gt;&lt;td style=&quot;padding-left:6px&quot;&gt;Medium&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td style=&quot;background:#0d9e3e; width:16px; height:16px; border-radius:3px&quot;&gt;&lt;/td&gt;&lt;td style=&quot;padding-left:6px&quot;&gt;Slow&lt;/td&gt;&lt;/tr&gt;
#         &lt;/table&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6387e344feadefa6f96df50401a36971&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6387e344feadefa6f96df50401a36971 = L.map(
#                 &quot;map_6387e344feadefa6f96df50401a36971&quot;,
#                 {
#                     center: [43.303705, 5.369789256],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_272636cd01f581d16f58ba21407499d5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_272636cd01f581d16f58ba21407499d5.addTo(map_6387e344feadefa6f96df50401a36971);
#
#
#             var poly_line_71687f0c7a2428ef16f16c12fe107fc1 = L.polyline(
#                 [[43.2965, 5.3701], [43.29659, 5.370094], [43.29668, 5.3700763], [43.29677, 5.3700476], [43.29686, 5.370009], [43.29695, 5.3699621], [43.29704, 5.3699087], [43.29713, 5.369851], [43.29722, 5.3697912], [43.29731, 5.3697318], [43.2974, 5.3696752], [43.29749, 5.3696234], [43.29758, 5.3695788], [43.29767, 5.3695429], [43.29776, 5.3695173], [43.29785, 5.369503], [43.29794, 5.3695005], [43.29803, 5.36951], [43.29812, 5.369531], [43.29821, 5.3695627], [43.2983, 5.3696039], [43.29839, 5.3696529], [43.29848, 5.3697078], [43.29857, 5.3697664], [43.29866, 5.3698262], [43.29875, 5.3698851], [43.29884, 5.3699406], [43.29893, 5.3699904], [43.29902, 5.3700327], [43.29911, 5.3700657], [43.2992, 5.3700881], [43.29929, 5.370099], [43.29938, 5.370098], [43.29947, 5.3700851], [43.29956, 5.3700608], [43.29965, 5.3700262], [43.29974, 5.3699825], [43.29983, 5.3699316], [43.29992, 5.3698754], [43.30001, 5.3698162], [43.3001, 5.3697563], [43.30019, 5.3696983], [43.30028, 5.3696442], [43.30037, 5.3695964], [43.30046, 5.3695567], [43.30055, 5.3695267], [43.30064, 5.3695075], [43.30073, 5.3695001], [43.30082, 5.3695046], [43.30091, 5.3695209]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1a73e8&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#1a73e8&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.85, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6387e344feadefa6f96df50401a36971);
#
#
#             poly_line_71687f0c7a2428ef16f16c12fe107fc1.bindTooltip(
#                 `&lt;div&gt;
#                      Fast — 50 points
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_d1a502236a8cc3a916755ec6496055c7 = L.marker(
#                 [43.2965, 5.3701],
#                 {
# }
#             ).addTo(map_6387e344feadefa6f96df50401a36971);
#
#
#             var icon_f96445a8f11895aa88b07de2a05df343 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;play&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_d1a502236a8cc3a916755ec6496055c7.bindTooltip(
#                 `&lt;div&gt;
#                      [Fast] Start
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_d1a502236a8cc3a916755ec6496055c7.setIcon(icon_f96445a8f11895

# %% [markdown]
# ## 3. 3-D trajectory plot
#
# `flight_3d()` uses `mpl_toolkits.mplot3d` to render a three-dimensional view of the flight path (longitude × latitude × altitude).
#
# - `color_by='speed'` — each segment is coloured by speed (green = slow, red = fast)
# - `azim` / `elev` — control the viewing angle
# - Events appear as orange triangles

# %%
fig = viz.flight_3d(mfx_fast)
plt.show()
# Out:
# /var/folders/1v/f0l_v3gs35b3lwyrxkgg9btr0000gp/T/ipykernel_52926/2757432269.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
# Colour segments by speed
fig_spd = viz.flight_3d(mfx_fast, color_by='speed')
plt.show()
# Out:
# /var/folders/1v/f0l_v3gs35b3lwyrxkgg9btr0000gp/T/ipykernel_52926/877771049.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
# Show events + custom view angle
fig_ev = viz.flight_3d(mfx_fast, color_by='speed', show_events=True, azim=30, elev=35)
fig_ev.savefig('flight_3d.png', dpi=150, bbox_inches='tight')
plt.show()
print("Saved to flight_3d.png")
# Out:
# Saved to flight_3d.png
# /var/folders/1v/f0l_v3gs35b3lwyrxkgg9btr0000gp/T/ipykernel_52926/2009431594.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
# Top-down view (looking straight down, elev=90)
fig_top = viz.flight_3d(mfx_fast, elev=89, azim=0, figsize=(8, 8))
fig_top.axes[0].set_title('Top-down view', fontsize=11)
plt.show()
# Out:
# /var/folders/1v/f0l_v3gs35b3lwyrxkgg9btr0000gp/T/ipykernel_52926/278586951.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ## Summary
#
# | Function | Returns | Description |
# |---|---|---|
# | `viz.speed_heatmap(mfx)` | `folium.Map` | Segments coloured green → red by speed |
# | `viz.compare_map([mfx1, mfx2, ...])` | `folium.Map` | Multiple flights with legend |
# | `viz.flight_3d(mfx, color_by='speed')` | `Figure` | 3-D lon / lat / alt matplotlib plot |
#
# All three accept `show_events=True/False` to overlay event markers.
